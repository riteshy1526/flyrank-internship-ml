# %%
df["trend_direction"].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# # Week 1 - Research Question
#
# ## 1. My Lane
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# ### Why I chose this lane
#
# I chose the **Refresh / Content Opportunity Scoring** lane because websites often contain thousands of pages, making it difficult for SEO teams to manually decide which pages should be refreshed first. A machine learning model can help prioritize pages that are more likely to benefit from content updates.

# %%
df.describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %% [markdown]
# ## 2. The Question
#
# ### Research Question
#
# Which webpages should be reviewed first for content refresh based on their search and content signals?
#
# ### Unit of Analysis
#
# One webpage (one content page).
#
# ### Output
#
# The model will generate a priority score (High, Medium, or Low) indicating which pages should be reviewed first.
#
# ### Decision
#
# The SEO or Content team will use the predictions to decide which pages should be refreshed before others.
#
# ### Action
#
# The team can update page content, improve metadata, expand information, or optimize keywords for the highest-priority pages.
#
# ### Cost of a Wrong Recommendation
#
# If the recommendation is incorrect, valuable pages may be ignored while less important pages are refreshed. This can waste time, effort, and reduce the opportunity to improve organic search performance.
#
# ### Why Machine Learning?
#
# The dataset contains thousands of webpages and many different features. Reviewing every page manually is difficult and time-consuming. Machine learning can identify useful patterns and help prioritize pages more efficiently, while still supporting human decision-making.

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/riteshy1526/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 3. Quick Look at the Data
#
# To better understand the problem, I explored the starter dataset before deciding my project direction.
#
# ### Key observations
#
# - The dataset contains **30,000 content pages** and **44 columns**.
# - **16,262 pages** are marked with a **"down"** trend, suggesting many pages have declining performance.
# - The average **search volume** is **158.88**.
# - The average **90-day impressions** are **5,200.37**.
#
# These numbers suggest that many pages may require review or refresh. Since manually checking thousands of pages is difficult, this dataset is suitable for building a machine learning model that helps prioritize which pages should be reviewed first.

# %% [markdown]
# ## 4. Careful Words
#
# This project does not prove that refreshing a page will improve its search performance.
#
# The model will identify patterns in historical data and provide recommendations to support decision-making. Final decisions should always include human judgment.

# %% [markdown]
# ## 5. Self Check
#
# - ✅ I selected a predefined lane.
# - ✅ I explained the research question.
# - ✅ I identified the decision and action.
# - ✅ I included real numbers from the dataset.
# - ✅ I explained why machine learning is useful.
# - ✅ I described the limitations of the project.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
